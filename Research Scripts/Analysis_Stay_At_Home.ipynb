# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
#Load Cleansed Data
df_analysis_StayAtHome = pd.read_csv('/content/Cleansed_Data.csv')

# %%
#Transform StayAtHomeRequirements Info
df_analysis_StayAtHome.loc[df_analysis_StayAtHome['StayAtHomeRequirements'] == 0, 'StayAtHomeRequirementsDetail'] = 'No_Measure'
df_analysis_StayAtHome.loc[df_analysis_StayAtHome['StayAtHomeRequirements'] == 1, 'StayAtHomeRequirementsDetail'] = 'Recommended_StayAtHome'
df_analysis_StayAtHome.loc[df_analysis_StayAtHome['StayAtHomeRequirements'] == 2, 'StayAtHomeRequirementsDetail'] = 'Required_StayAtHome_Few'
df_analysis_StayAtHome.loc[df_analysis_StayAtHome['StayAtHomeRequirements'] == 3, 'StayAtHomeRequirementsDetail'] = 'Required_StayAtHome_All'

# %%
df_analysis_StayAtHome['Date'] = pd.to_datetime(df_analysis_StayAtHome.Date, format= '%Y-%m-%d')
df_analysis_StayAtHome['Month'] = df_analysis_StayAtHome['Date'].dt.strftime("%m")
df_analysis_StayAtHome['Week_Number'] = df_analysis_StayAtHome['Date'].dt.isocalendar().week

# %%
#Find Daily Case Using Shift()
df_analysis_StayAtHome['Lagged_Confirmed_Case'] = df_analysis_StayAtHome.groupby(['Country', 'State'])['ConfirmedCases'].shift(1)
df_analysis_StayAtHome['Daily_New_Cases'] = df_analysis_StayAtHome['ConfirmedCases'] - df_analysis_StayAtHome['Lagged_Confirmed_Case']

# %%
#Select Specific Columns
df_analysis_StayAtHome = df_analysis_StayAtHome[[
    'Country', 'State', 'Date', 'StayAtHomeRequirements', 'StayAtHomeRequirementsDetail', 'ConfirmedCases', 'Daily_New_Cases', 'Month', 'Week_Number'
]]

# %%
#Find Max Confirmed Cases per State and Save to CSV
df_MaxCases_Per_State = df_analysis_StayAtHome.groupby('State')['ConfirmedCases'].max().reset_index().sort_values(by=['ConfirmedCases'], ascending= False)
df_MaxCases_Per_State['Rank'] = df_MaxCases_Per_State['ConfirmedCases'].rank(ascending= False)
df_MaxCases_Per_State.to_csv(r"MaxConfirmedCasesPerState.csv", index= False)

# %%
#Select States
df_Wisconsin = df_analysis_StayAtHome[(df_analysis_StayAtHome['State'] == "Wisconsin")]
df_Wisconsin= df_Wisconsin[[
    'Country', 'State', 'StayAtHomeRequirementsDetail', 'Daily_New_Cases', 'Month', 'Week_Number'
]]
df_Wisconsin.groupby(['State', 'StayAtHomeRequirementsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'], ascending= True)
# Out:
#         State StayAtHomeRequirementsDetail Month  Week_Number  Weekly_Cases
# 0   Wisconsin                   No_Measure    03            9           0.0
# 1   Wisconsin                   No_Measure    03           10           0.0
# 2   Wisconsin                   No_Measure    03           11          28.0
# 3   Wisconsin                   No_Measure    03           12         353.0
# 4   Wisconsin                   No_Measure    03           13         100.0
# 39  Wisconsin      Required_StayAtHome_Few    03           13         683.0
# 40  Wisconsin      Required_StayAtHome_Few    03           14         248.0
# 41  Wisconsin      Required_StayAtHome_Few    04           14         908.0
# 42  Wisconsin      Required_StayAtHome_Few    04           15        1021.0
# 43  Wisconsin      Required_StayAtHome_Few    04           16        1005.0
# 44  Wisconsin      Required_StayAtHome_Few    04           17        1566.0
# ...

# %%
df_Washington = df_analysis_StayAtHome[(df_analysis_StayAtHome['State'] == "Washington")]
df_Washington= df_Washington[[
    'Country', 'State', 'StayAtHomeRequirementsDetail', 'Daily_New_Cases', 'Month', 'Week_Number'
]]
df_Washington.groupby(['State', 'StayAtHomeRequirementsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'], ascending= True)
# Out:
#          State StayAtHomeRequirementsDetail Month  Week_Number  Weekly_Cases
# 0   Washington                   No_Measure    03            9           0.0
# 1   Washington                   No_Measure    03           10          16.0
# 2   Washington       Recommended_StayAtHome    03           10          95.0
# 3   Washington       Recommended_StayAtHome    03           11         481.0
# 4   Washington       Recommended_StayAtHome    03           12        1394.0
# 37  Washington      Required_StayAtHome_Few    03           13        2468.0
# 38  Washington      Required_StayAtHome_Few    03           14         967.0
# 39  Washington      Required_StayAtHome_Few    04           14        2393.0
# 40  Washington      Required_StayAtHome_Few    04           15        2784.0
# 41  Washington      Required_StayAtHome_Few    04           16        1369.0
# 42  Washington      Required_StayAtHome_Few    04           17        1543.0
# ...

# %%
df_NewJersey = df_analysis_StayAtHome[(df_analysis_StayAtHome['State'] == "New Jersey")]
df_NewJersey= df_NewJersey[[
    'Country', 'State', 'StayAtHomeRequirementsDetail', 'Daily_New_Cases', 'Month', 'Week_Number'
]]
df_NewJersey.groupby(['State', 'StayAtHomeRequirementsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'], ascending= True)
# Out:
#          State StayAtHomeRequirementsDetail Month  Week_Number  Weekly_Cases
# 0   New Jersey                   No_Measure    03            9           0.0
# 1   New Jersey                   No_Measure    03           10           5.0
# 2   New Jersey                   No_Measure    03           11          67.0
# 3   New Jersey                   No_Measure    03           12         818.0
# 34  New Jersey      Required_StayAtHome_Few    03           12        1024.0
# 35  New Jersey      Required_StayAtHome_Few    03           13       11472.0
# 36  New Jersey      Required_StayAtHome_Few    03           14        5310.0
# 37  New Jersey      Required_StayAtHome_Few    04           14       18809.0
# 38  New Jersey      Required_StayAtHome_Few    04           15       24345.0
# 39  New Jersey      Required_StayAtHome_Few    04           16       23451.0
# 40  New Jersey      Required_StayAtHome_Few    04           17       23737.0
# ...

# %%
df_Oregon = df_analysis_StayAtHome[(df_analysis_StayAtHome['State'] == "Oregon")]
df_Oregon= df_Oregon[[
    'Country', 'State', 'StayAtHomeRequirementsDetail', 'Daily_New_Cases', 'Month', 'Week_Number'
]]
df_Oregon.groupby(['State', 'StayAtHomeRequirementsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'], ascending= True)
# Out:
#      State StayAtHomeRequirementsDetail Month  Week_Number  Weekly_Cases
# 0   Oregon                   No_Measure    03            9           0.0
# 1   Oregon                   No_Measure    03           10          13.0
# 2   Oregon                   No_Measure    03           11          22.0
# 3   Oregon                   No_Measure    03           12         125.0
# 4   Oregon                   No_Measure    03           13         155.0
# 34  Oregon      Required_StayAtHome_Few    03           13         232.0
# 35  Oregon      Required_StayAtHome_Few    03           14         142.0
# 36  Oregon      Required_StayAtHome_Few    04           14         378.0
# 37  Oregon      Required_StayAtHome_Few    04           15         459.0
# 38  Oregon      Required_StayAtHome_Few    04           16         383.0
# 39  Oregon      Required_StayAtHome_Few    04           17         401.0
# 40  Oregon      Required_StayAtHome_Few    04           18         199.0
# ...

# %%
df_Tennessee = df_analysis_StayAtHome[(df_analysis_StayAtHome['State'] == "Tennessee")]
df_Tennessee= df_Tennessee[[
    'Country', 'State', 'StayAtHomeRequirementsDetail', 'Daily_New_Cases', 'Month', 'Week_Number'
]]
df_Tennessee.groupby(['State', 'StayAtHomeRequirementsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'], ascending= True)
# Out:
#         State StayAtHomeRequirementsDetail Month  Week_Number  Weekly_Cases
# 0   Tennessee                   No_Measure    03            9           0.0
# 1   Tennessee                   No_Measure    03           10           3.0
# 2   Tennessee                   No_Measure    03           11          15.0
# 3   Tennessee       Recommended_StayAtHome    03           11          14.0
# 40  Tennessee      Required_StayAtHome_Few    03           11           0.0
# 41  Tennessee      Required_StayAtHome_Few    03           12         361.0
# 42  Tennessee      Required_StayAtHome_Few    03           13        1327.0
# 43  Tennessee      Required_StayAtHome_Few    03           14         671.0
# 44  Tennessee      Required_StayAtHome_Few    04           14        1269.0
# 45  Tennessee      Required_StayAtHome_Few    04           15        1730.0
# 46  Tennessee      Required_StayAtHome_Few    04           16        1721.0
# ...

# %%
df_NewYork = df_analysis_StayAtHome[(df_analysis_StayAtHome['State'] == "New York")]
df_NewYork= df_NewYork[[
    'Country', 'State', 'StayAtHomeRequirementsDetail', 'Daily_New_Cases', 'Month', 'Week_Number'
]]
df_NewYork.groupby(['State', 'StayAtHomeRequirementsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'], ascending= True)
# Out:
#        State StayAtHomeRequirementsDetail Month  Week_Number  Weekly_Cases
# 0   New York                   No_Measure    03            9           0.0
# 1   New York                   No_Measure    03           10         105.0
# 2   New York       Recommended_StayAtHome    03           11         528.0
# 3   New York       Recommended_StayAtHome    03           12        9777.0
# 35  New York      Required_StayAtHome_Few    03           12        4781.0
# 36  New York      Required_StayAtHome_Few    03           13       44457.0
# 37  New York      Required_StayAtHome_Few    03           14       16205.0
# 38  New York      Required_StayAtHome_Few    04           14       56847.0
# 39  New York      Required_StayAtHome_Few    04           15       67935.0
# 40  New York      Required_StayAtHome_Few    04           16       50378.0
# 41  New York      Required_StayAtHome_Few    04           17       42562.0
# ...

# %%
df_Texas = df_analysis_StayAtHome[(df_analysis_StayAtHome['State'] == "Texas")]
df_Texas= df_Texas[[
    'Country', 'State', 'StayAtHomeRequirementsDetail', 'Daily_New_Cases', 'Month', 'Week_Number'
]]
df_Texas.groupby(['State', 'StayAtHomeRequirementsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'], ascending= True)
# Out:
#     State StayAtHomeRequirementsDetail Month  Week_Number  Weekly_Cases
# 0   Texas                   No_Measure    03            9           0.0
# 1   Texas                   No_Measure    03           10          11.0
# 2   Texas                   No_Measure    03           11          53.0
# 3   Texas                   No_Measure    03           12         242.0
# 4   Texas       Recommended_StayAtHome    03           12         337.0
# 39  Texas      Required_StayAtHome_Few    03           13        2149.0
# 40  Texas      Required_StayAtHome_Few    03           14        1017.0
# 41  Texas      Required_StayAtHome_Few    04           14        1595.0
# 42  Texas      Required_StayAtHome_Few    04           15        4393.0
# 43  Texas      Required_StayAtHome_Few    04           16        3977.0
# 44  Texas      Required_StayAtHome_Few    04           17        5006.0
# 45  Texas      Required_StayAtHome_Few    04           18        4663.0
# ...

# %%
df_Arizona = df_analysis_StayAtHome[(df_analysis_StayAtHome['State'] == "Arizona")]
df_Arizona= df_Arizona[[
    'Country', 'State', 'StayAtHomeRequirementsDetail', 'Daily_New_Cases', 'Month', 'Week_Number'
]]
df_Arizona.groupby(['State', 'StayAtHomeRequirementsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'], ascending= True)
# Out:
#       State StayAtHomeRequirementsDetail Month  Week_Number  Weekly_Cases
# 0   Arizona                   No_Measure    03            9           0.0
# 1   Arizona                   No_Measure    03           10           3.0
# 2   Arizona                   No_Measure    03           11           8.0
# 3   Arizona                   No_Measure    03           12         140.0
# 4   Arizona                   No_Measure    03           13         767.0
# 5   Arizona                   No_Measure    03           14         238.0
# 41  Arizona      Required_StayAtHome_Few    03           14         132.0
# 42  Arizona      Required_StayAtHome_Few    04           14         980.0
# 43  Arizona      Required_StayAtHome_Few    04           15        1273.0
# 44  Arizona      Required_StayAtHome_Few    04           16        1391.0
# 45  Arizona      Required_StayAtHome_Few    04           17        1601.0
# 46  Arizona      Required_StayAtHome_Few    04           18        1121.0
# ...

# %%
df_RhodeIsland = df_analysis_StayAtHome[(df_analysis_StayAtHome['State'] == "Rhode Island")]
df_RhodeIsland= df_RhodeIsland[[
    'Country', 'State', 'StayAtHomeRequirementsDetail', 'Daily_New_Cases', 'Month', 'Week_Number'
]]
df_RhodeIsland.groupby(['State', 'StayAtHomeRequirementsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'], ascending= True)
# Out:
#            State StayAtHomeRequirementsDetail Month  Week_Number  Weekly_Cases
# 0   Rhode Island                   No_Measure    03            9           0.0
# 1   Rhode Island                   No_Measure    03           10           2.0
# 2   Rhode Island                   No_Measure    03           11          17.0
# 3   Rhode Island       Recommended_StayAtHome    03           12          63.0
# 4   Rhode Island       Recommended_StayAtHome    03           13          23.0
# 38  Rhode Island      Required_StayAtHome_Few    03           13         188.0
# 39  Rhode Island      Required_StayAtHome_Few    03           14         194.0
# 40  Rhode Island      Required_StayAtHome_Few    04           14         434.0
# 41  Rhode Island      Required_StayAtHome_Few    04           15        1743.0
# 42  Rhode Island      Required_StayAtHome_Few    04           16        2041.0
# 43  Rhode Island      Required_StayAtHome_Few    04           17        2733.0
# ...

# %%
df_Connecticut = df_analysis_StayAtHome[(df_analysis_StayAtHome['State'] == "Connecticut")]
df_Connecticut= df_Connecticut[[
    'Country', 'State', 'StayAtHomeRequirementsDetail', 'Daily_New_Cases', 'Month', 'Week_Number'
]]
df_Connecticut.groupby(['State', 'StayAtHomeRequirementsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'], ascending= True)
# Out:
#           State StayAtHomeRequirementsDetail Month  Week_Number  Weekly_Cases
# 0   Connecticut                   No_Measure    03            9           0.0
# 1   Connecticut                   No_Measure    03           10           0.0
# 2   Connecticut                   No_Measure    03           11          24.0
# 3   Connecticut                   No_Measure    03           12         170.0
# 4   Connecticut       Recommended_StayAtHome    03           12         133.0
# 5   Connecticut       Recommended_StayAtHome    03           13        1666.0
# 6   Connecticut       Recommended_StayAtHome    03           14        1135.0
# 7   Connecticut       Recommended_StayAtHome    04           14        2547.0
# 8   Connecticut       Recommended_StayAtHome    04           15        6360.0
# 9   Connecticut       Recommended_StayAtHome    04           16        5927.0
# 10  Connecticut       Recommended_StayAtHome    04           17        7307.0
# ...

# %%
df_WashingtonDC = df_analysis_StayAtHome[(df_analysis_StayAtHome['State'] == "Washington DC")]
df_WashingtonDC= df_WashingtonDC[[
    'Country', 'State', 'StayAtHomeRequirementsDetail', 'Daily_New_Cases', 'Month', 'Week_Number'
]]
df_WashingtonDC.groupby(['State', 'StayAtHomeRequirementsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'], ascending= True)
# Out:
#             State StayAtHomeRequirementsDetail Month  Week_Number  \
# 0   Washington DC                   No_Measure    03            9
# 1   Washington DC                   No_Measure    03           10
# 2   Washington DC                   No_Measure    03           11
# 3   Washington DC                   No_Measure    03           12
# 4   Washington DC                   No_Measure    03           13
# 5   Washington DC                   No_Measure    03           14
# 39  Washington DC      Required_StayAtHome_Few    04           14
# 40  Washington DC      Required_StayAtHome_Few    04           15
# 41  Washington DC      Required_StayAtHome_Few    04           16
# 42  Washington DC      Required_StayAtHome_Few    04           17
# 43  Washington DC      Required_StayAtHome_Few    04           18
# 44  Washington DC      Required_StayAtHome_Few    05           18
# 45  Washington DC      Required_StayAtHome_Few    05           19
# ...

# %%
df_Utah = df_analysis_StayAtHome[(df_analysis_StayAtHome['State'] == "Utah")]
df_Utah= df_Utah[[
    'Country', 'State', 'StayAtHomeRequirementsDetail', 'Daily_New_Cases', 'Month', 'Week_Number'
]]
df_Utah.groupby(['State', 'StayAtHomeRequirementsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'], ascending= True)
# Out:
#    State StayAtHomeRequirementsDetail Month  Week_Number  Weekly_Cases
# 0   Utah                   No_Measure    03            9           0.0
# 1   Utah                   No_Measure    03           10           1.0
# 2   Utah                   No_Measure    03           11          17.0
# 3   Utah                   No_Measure    03           12         144.0
# 4   Utah                   No_Measure    03           13         234.0
# 5   Utah       Recommended_StayAtHome    03           13         324.0
# 6   Utah       Recommended_StayAtHome    03           14         168.0
# 7   Utah       Recommended_StayAtHome    04           14         713.0
# 8   Utah       Recommended_StayAtHome    04           15         702.0
# 9   Utah       Recommended_StayAtHome    04           16         766.0
# 10  Utah       Recommended_StayAtHome    04           17        1054.0
# 11  Utah       Recommended_StayAtHome    04           18         549.0
# ...

# %%
df_Wyoming = df_analysis_StayAtHome[(df_analysis_StayAtHome['State'] == "Wyoming")]
df_Wyoming= df_Wyoming[[
    'Country', 'State', 'StayAtHomeRequirementsDetail', 'Daily_New_Cases', 'Month', 'Week_Number'
]]
df_Wyoming.groupby(['State', 'StayAtHomeRequirementsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'], ascending= True)
# Out:
#       State StayAtHomeRequirementsDetail Month  Week_Number  Weekly_Cases
# 0   Wyoming                   No_Measure    03            9           0.0
# 1   Wyoming                   No_Measure    03           10           0.0
# 2   Wyoming                   No_Measure    03           11           2.0
# 3   Wyoming                   No_Measure    03           12          24.0
# 4   Wyoming                   No_Measure    03           13           3.0
# 5   Wyoming       Recommended_StayAtHome    03           13          57.0
# 6   Wyoming       Recommended_StayAtHome    03           14          23.0
# 7   Wyoming       Recommended_StayAtHome    04           14          88.0
# 8   Wyoming       Recommended_StayAtHome    04           15          73.0
# 9   Wyoming       Recommended_StayAtHome    04           16          43.0
# 10  Wyoming       Recommended_StayAtHome    04           17         189.0
# 11  Wyoming       Recommended_StayAtHome    04           18          57.0
# ...

# %%
df_Hawaii = df_analysis_StayAtHome[(df_analysis_StayAtHome['State'] == "Hawaii")]
df_Hawaii= df_Hawaii[[
    'Country', 'State', 'StayAtHomeRequirementsDetail', 'Daily_New_Cases', 'Month', 'Week_Number'
]]
df_Hawaii.groupby(['State', 'StayAtHomeRequirementsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'], ascending= True)
# Out:
#      State StayAtHomeRequirementsDetail Month  Week_Number  Weekly_Cases
# 0   Hawaii                   No_Measure    03            9           0.0
# 1   Hawaii                   No_Measure    03           10           1.0
# 2   Hawaii                   No_Measure    03           11           5.0
# 3   Hawaii                   No_Measure    03           12          19.0
# 8   Hawaii      Required_StayAtHome_Few    03           12          28.0
# 9   Hawaii      Required_StayAtHome_Few    03           13          96.0
# 10  Hawaii      Required_StayAtHome_Few    03           14          55.0
# 11  Hawaii      Required_StayAtHome_Few    04           14         167.0
# 12  Hawaii      Required_StayAtHome_Few    04           15         128.0
# 13  Hawaii      Required_StayAtHome_Few    04           16          81.0
# 14  Hawaii      Required_StayAtHome_Few    04           17          26.0
# 15  Hawaii      Required_StayAtHome_Few    04           18          12.0
# ...

# %%
df_Maine = df_analysis_StayAtHome[(df_analysis_StayAtHome['State'] == "Maine")]
df_Maine= df_Maine[[
    'Country', 'State', 'StayAtHomeRequirementsDetail', 'Daily_New_Cases', 'Month', 'Week_Number'
]]
df_Maine.groupby(['State', 'StayAtHomeRequirementsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'], ascending= True)
# Out:
#     State StayAtHomeRequirementsDetail Month  Week_Number  Weekly_Cases
# 0   Maine                   No_Measure    03            9           0.0
# 1   Maine                   No_Measure    03           10           0.0
# 2   Maine                   No_Measure    03           11           2.0
# 3   Maine                   No_Measure    03           12          87.0
# 4   Maine                   No_Measure    03           13          29.0
# 38  Maine      Required_StayAtHome_Few    03           13         135.0
# 39  Maine      Required_StayAtHome_Few    03           14          50.0
# 40  Maine      Required_StayAtHome_Few    04           14         167.0
# 41  Maine      Required_StayAtHome_Few    04           15         163.0
# 42  Maine      Required_StayAtHome_Few    04           16         234.0
# 43  Maine      Required_StayAtHome_Few    04           17         148.0
# 44  Maine      Required_StayAtHome_Few    04           18          80.0
# ...

# %%
df_Vermont = df_analysis_StayAtHome[(df_analysis_StayAtHome['State'] == "Vermont")]
df_Vermont= df_Vermont[[
    'Country', 'State', 'StayAtHomeRequirementsDetail', 'Daily_New_Cases', 'Month', 'Week_Number'
]]
df_Vermont.groupby(['State', 'StayAtHomeRequirementsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'], ascending= True)
# Out:
#       State StayAtHomeRequirementsDetail Month  Week_Number  Weekly_Cases
# 0   Vermont                   No_Measure    03            9           0.0
# 1   Vermont                   No_Measure    03           10           1.0
# 2   Vermont                   No_Measure    03           11           4.0
# 3   Vermont                   No_Measure    03           12          47.0
# 4   Vermont                   No_Measure    03           13          23.0
# 41  Vermont      Required_StayAtHome_Few    03           13         160.0
# 42  Vermont      Required_StayAtHome_Few    03           14          58.0
# 43  Vermont      Required_StayAtHome_Few    04           14         219.0
# 44  Vermont      Required_StayAtHome_Few    04           15         215.0
# 45  Vermont      Required_StayAtHome_Few    04           16          86.0
# 46  Vermont      Required_StayAtHome_Few    04           17          38.0
# 47  Vermont      Required_StayAtHome_Few    04           18          15.0
# ...
