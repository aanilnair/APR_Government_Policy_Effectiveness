# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
#Load Cleansed Data
df_analysis_internal_restrictions = pd.read_csv('/content/Cleansed_Data.csv')

# %%
#Changing Date Datatype
df_analysis_internal_restrictions = df_analysis_internal_restrictions.rename(columns = {'Date' : 'OldDate'})
df_analysis_internal_restrictions['Date'] = pd.to_datetime(df_analysis_internal_restrictions['OldDate'], format='%Y-%m-%d')

# %%
#Transform Workplace Closing Info
df_analysis_internal_restrictions.loc[df_analysis_internal_restrictions['InternalRestrictions'] == 0, 'InternalRestrictionsDetail'] = 'No_Measure'
df_analysis_internal_restrictions.loc[df_analysis_internal_restrictions['InternalRestrictions'] == 1, 'InternalRestrictionsDetail'] = 'Reccommended_Restriction'
df_analysis_internal_restrictions.loc[df_analysis_internal_restrictions['InternalRestrictions'] == 2, 'InternalRestrictionsDetail'] = 'Required_Restriction'

# %%
#Find Daily Case Using Shift()
df_analysis_internal_restrictions['Lagged_Confirmed_Case'] = df_analysis_internal_restrictions.groupby(['Country','State'])['ConfirmedCases'].shift(1)
df_analysis_internal_restrictions['Daily_New_Cases'] = df_analysis_internal_restrictions['ConfirmedCases'] - df_analysis_internal_restrictions['Lagged_Confirmed_Case']

# %%
df_analysis_internal_restrictions['Date'] = pd.to_datetime(df_analysis_internal_restrictions.Date, format='%Y-%m-%d')
df_analysis_internal_restrictions['Month'] = df_analysis_internal_restrictions['Date'].dt.strftime('%m')
df_analysis_internal_restrictions['Week_Number'] = df_analysis_internal_restrictions['Date'].dt.isocalendar().week

# %%
#Select Specefic Columns
df_analysis_internal_restrictions = df_analysis_internal_restrictions[[
    'Country',
    'State' ,
    'Date' ,
    'InternalRestrictions',
    'InternalRestrictionsDetail' ,
    'ConfirmedCases' ,
    'Daily_New_Cases' ,
    'Month' ,
    'Week_Number'
    ]]

# %%
#Select Wisconsin
df_Wisconsin = df_analysis_internal_restrictions[((df_analysis_internal_restrictions['State']== 'Wisconsin'))]
df_Wisconsin = df_Wisconsin[[
    'Country',
    'State' ,
    'InternalRestrictionsDetail' ,
    'Daily_New_Cases',
    'Month' ,
    'Week_Number'
    ]]
df_Wisconsin.groupby(['State', 'InternalRestrictionsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'],ascending= True)
# Out:
#         State InternalRestrictionsDetail Month  Week_Number  Weekly_Cases
# 0   Wisconsin                 No_Measure    03            9           0.0
# 1   Wisconsin                 No_Measure    03           10           0.0
# 2   Wisconsin                 No_Measure    03           11           4.0
# 3   Wisconsin   Reccommended_Restriction    03           11          24.0
# 4   Wisconsin   Reccommended_Restriction    03           12         353.0
# 5   Wisconsin   Reccommended_Restriction    03           13         783.0
# 6   Wisconsin   Reccommended_Restriction    03           14         248.0
# 7   Wisconsin   Reccommended_Restriction    04           14         908.0
# 8   Wisconsin   Reccommended_Restriction    04           15        1021.0
# 9   Wisconsin   Reccommended_Restriction    04           16        1005.0
# 10  Wisconsin   Reccommended_Restriction    04           17        1566.0
# 11  Wisconsin   Reccommended_Restriction    04           18         942.0
# ...

# %%
#Select Washington
df_Washington = df_analysis_internal_restrictions[((df_analysis_internal_restrictions['State']== 'Washington'))]
df_Washington = df_Washington[[
    'Country',
    'State' ,
    'InternalRestrictionsDetail' ,
    'Daily_New_Cases',
    'Month' ,
    'Week_Number'
    ]]
df_Washington.groupby(['State', 'InternalRestrictionsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'],ascending= True)
# Out:
#          State InternalRestrictionsDetail Month  Week_Number  Weekly_Cases
# 0   Washington                 No_Measure    03            9           0.0
# 1   Washington                 No_Measure    03           10         111.0
# 2   Washington                 No_Measure    03           11         481.0
# 3   Washington   Reccommended_Restriction    03           12        1394.0
# 4   Washington   Reccommended_Restriction    03           13        2468.0
# 5   Washington   Reccommended_Restriction    03           14         967.0
# 6   Washington   Reccommended_Restriction    04           14        2393.0
# 7   Washington   Reccommended_Restriction    04           15        2784.0
# 8   Washington   Reccommended_Restriction    04           16        1369.0
# 9   Washington   Reccommended_Restriction    04           17        1543.0
# 10  Washington   Reccommended_Restriction    04           18         806.0
# ...

# %%
#Select New Jersey
df_New_Jersey = df_analysis_internal_restrictions[((df_analysis_internal_restrictions['State']== 'New Jersey'))]
df_New_Jersey = df_New_Jersey[[
    'Country',
    'State' ,
    'InternalRestrictionsDetail' ,
    'Daily_New_Cases',
    'Month' ,
    'Week_Number'
    ]]
df_New_Jersey.groupby(['State', 'InternalRestrictionsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'],ascending= True)
# Out:
#          State InternalRestrictionsDetail Month  Week_Number  Weekly_Cases
# 0   New Jersey                 No_Measure    03            9           0.0
# 1   New Jersey                 No_Measure    03           10           5.0
# 2   New Jersey                 No_Measure    03           11          67.0
# 3   New Jersey   Reccommended_Restriction    03           12        1842.0
# 4   New Jersey   Reccommended_Restriction    03           13       11472.0
# 5   New Jersey   Reccommended_Restriction    03           14        5310.0
# 6   New Jersey   Reccommended_Restriction    04           14       18809.0
# 7   New Jersey   Reccommended_Restriction    04           15       24345.0
# 8   New Jersey   Reccommended_Restriction    04           16       23451.0
# 9   New Jersey   Reccommended_Restriction    04           17       23737.0
# 10  New Jersey   Reccommended_Restriction    04           18        9614.0
# ...

# %%
#Select Oregon
df_Oregon = df_analysis_internal_restrictions[((df_analysis_internal_restrictions['State']== 'Oregon'))]
df_Oregon = df_Oregon[[
    'Country',
    'State' ,
    'InternalRestrictionsDetail' ,
    'Daily_New_Cases',
    'Month' ,
    'Week_Number'
    ]]
df_Oregon.groupby(['State', 'InternalRestrictionsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'],ascending= True)
# Out:
#      State InternalRestrictionsDetail Month  Week_Number  Weekly_Cases
# 0   Oregon                 No_Measure    03            9           0.0
# 1   Oregon                 No_Measure    03           10          13.0
# 2   Oregon                 No_Measure    03           11          22.0
# 3   Oregon   Reccommended_Restriction    03           12         125.0
# 4   Oregon   Reccommended_Restriction    03           13          30.0
# 41  Oregon       Required_Restriction    03           13         357.0
# 42  Oregon       Required_Restriction    03           14         142.0
# 43  Oregon       Required_Restriction    04           14         378.0
# 44  Oregon       Required_Restriction    04           15         459.0
# 45  Oregon       Required_Restriction    04           16         383.0
# 46  Oregon       Required_Restriction    04           17         401.0
# 47  Oregon       Required_Restriction    04           18         199.0
# ...

# %%
#Select Tennessee
df_Tennessee = df_analysis_internal_restrictions[((df_analysis_internal_restrictions['State']== 'Tennessee'))]
df_Tennessee = df_Tennessee[[
    'Country',
    'State' ,
    'InternalRestrictionsDetail' ,
    'Daily_New_Cases',
    'Month' ,
    'Week_Number'
    ]]
df_Tennessee.groupby(['State', 'InternalRestrictionsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'],ascending= True)
# Out:
#         State InternalRestrictionsDetail Month  Week_Number  Weekly_Cases
# 0   Tennessee                 No_Measure    03            9           0.0
# 1   Tennessee                 No_Measure    03           10           3.0
# 2   Tennessee                 No_Measure    03           11          15.0
# 3   Tennessee   Reccommended_Restriction    03           11          14.0
# 4   Tennessee   Reccommended_Restriction    03           12         361.0
# 5   Tennessee   Reccommended_Restriction    03           13        1327.0
# 6   Tennessee   Reccommended_Restriction    03           14         671.0
# 7   Tennessee   Reccommended_Restriction    04           14        1269.0
# 8   Tennessee   Reccommended_Restriction    04           15        1730.0
# 9   Tennessee   Reccommended_Restriction    04           16        1721.0
# 10  Tennessee   Reccommended_Restriction    04           17        2556.0
# 11  Tennessee   Reccommended_Restriction    04           18        2140.0
# ...

# %%
#Select New York
df_New_York = df_analysis_internal_restrictions[((df_analysis_internal_restrictions['State']== 'New York'))]
df_New_York = df_New_York[[
    'Country',
    'State' ,
    'InternalRestrictionsDetail' ,
    'Daily_New_Cases',
    'Month' ,
    'Week_Number'
    ]]
df_New_York.groupby(['State', 'InternalRestrictionsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'],ascending= True)
# Out:
#        State InternalRestrictionsDetail Month  Week_Number  Weekly_Cases
# 0   New York                 No_Measure    03            9           0.0
# 1   New York                 No_Measure    03           10         105.0
# 2   New York                 No_Measure    03           11         528.0
# 3   New York   Reccommended_Restriction    03           12       14558.0
# 4   New York   Reccommended_Restriction    03           13       44457.0
# 5   New York   Reccommended_Restriction    03           14       16205.0
# 6   New York   Reccommended_Restriction    04           14       56847.0
# 7   New York   Reccommended_Restriction    04           15       67935.0
# 8   New York   Reccommended_Restriction    04           16       50378.0
# 9   New York   Reccommended_Restriction    04           17       42562.0
# 10  New York   Reccommended_Restriction    04           18       14734.0
# 11  New York   Reccommended_Restriction    05           18       12376.0
# ...

# %% [markdown]
# Analysis Based on Population Density

# %%
#Select Texas
df_Texas = df_analysis_internal_restrictions[((df_analysis_internal_restrictions['State']== 'Texas'))]
df_Texas = df_Texas[[
    'Country',
    'State' ,
    'InternalRestrictionsDetail' ,
    'Daily_New_Cases',
    'Month' ,
    'Week_Number'
    ]]
df_Texas.groupby(['State', 'InternalRestrictionsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'],ascending= True)
# Out:
#     State InternalRestrictionsDetail Month  Week_Number  Weekly_Cases
# 0   Texas                 No_Measure    03            9           0.0
# 1   Texas                 No_Measure    03           10          11.0
# 2   Texas                 No_Measure    03           11          53.0
# 3   Texas   Reccommended_Restriction    03           12         579.0
# 4   Texas   Reccommended_Restriction    03           13        1294.0
# 39  Texas       Required_Restriction    03           13         855.0
# 40  Texas       Required_Restriction    03           14        1017.0
# 41  Texas       Required_Restriction    04           14        1595.0
# 42  Texas       Required_Restriction    04           15        4393.0
# 43  Texas       Required_Restriction    04           16        3977.0
# 44  Texas       Required_Restriction    04           17        5006.0
# 45  Texas       Required_Restriction    04           18        4663.0
# ...

# %%
#Select Arizona
df_Arizona = df_analysis_internal_restrictions[((df_analysis_internal_restrictions['State']== 'Arizona'))]
df_Arizona = df_Arizona[[
    'Country',
    'State' ,
    'InternalRestrictionsDetail' ,
    'Daily_New_Cases',
    'Month' ,
    'Week_Number'
    ]]
df_Arizona.groupby(['State', 'InternalRestrictionsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'],ascending= True)
# Out:
#       State InternalRestrictionsDetail Month  Week_Number  Weekly_Cases
# 0   Arizona                 No_Measure    03            9           0.0
# 1   Arizona                 No_Measure    03           10           3.0
# 2   Arizona                 No_Measure    03           11           8.0
# 3   Arizona   Reccommended_Restriction    03           12         140.0
# 4   Arizona   Reccommended_Restriction    03           13         767.0
# 5   Arizona   Reccommended_Restriction    03           14         370.0
# 6   Arizona   Reccommended_Restriction    04           14         980.0
# 7   Arizona   Reccommended_Restriction    04           15         457.0
# 43  Arizona       Required_Restriction    04           15         816.0
# 44  Arizona       Required_Restriction    04           16        1391.0
# 45  Arizona       Required_Restriction    04           17        1601.0
# 46  Arizona       Required_Restriction    04           18        1121.0
# ...

# %%
#Select Rhode Island
df_Rhode_Island = df_analysis_internal_restrictions[((df_analysis_internal_restrictions['State']== 'Rhode Island'))]
df_Rhode_Island = df_Rhode_Island[[
    'Country',
    'State' ,
    'InternalRestrictionsDetail' ,
    'Daily_New_Cases',
    'Month' ,
    'Week_Number'
    ]]
df_Rhode_Island.groupby(['State', 'InternalRestrictionsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'],ascending= True)
# Out:
#            State InternalRestrictionsDetail Month  Week_Number  Weekly_Cases
# 0   Rhode Island                 No_Measure    03            9           0.0
# 1   Rhode Island                 No_Measure    03           10           2.0
# 2   Rhode Island                 No_Measure    03           11          17.0
# 3   Rhode Island   Reccommended_Restriction    03           12          63.0
# 4   Rhode Island   Reccommended_Restriction    03           13          23.0
# 5   Rhode Island       Required_Restriction    03           13         188.0
# 6   Rhode Island       Required_Restriction    03           14         194.0
# 7   Rhode Island       Required_Restriction    04           14         434.0
# 8   Rhode Island       Required_Restriction    04           15        1743.0
# 9   Rhode Island       Required_Restriction    04           16        2041.0
# 10  Rhode Island       Required_Restriction    04           17        2733.0
# ...

# %%
#Select Connecticut
df_Connecticut = df_analysis_internal_restrictions[((df_analysis_internal_restrictions['State']== 'Connecticut'))]
df_Connecticut = df_Connecticut[[
    'Country',
    'State' ,
    'InternalRestrictionsDetail' ,
    'Daily_New_Cases',
    'Month' ,
    'Week_Number'
    ]]
df_Connecticut.groupby(['State', 'InternalRestrictionsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'],ascending= True)
# Out:
#           State InternalRestrictionsDetail Month  Week_Number  Weekly_Cases
# 0   Connecticut                 No_Measure    03            9           0.0
# 1   Connecticut                 No_Measure    03           10           0.0
# 2   Connecticut                 No_Measure    03           11          24.0
# 3   Connecticut   Reccommended_Restriction    03           12         303.0
# 4   Connecticut   Reccommended_Restriction    03           13        1666.0
# 5   Connecticut   Reccommended_Restriction    03           14        1135.0
# 6   Connecticut   Reccommended_Restriction    04           14        2547.0
# 7   Connecticut   Reccommended_Restriction    04           15        6360.0
# 8   Connecticut   Reccommended_Restriction    04           16        5927.0
# 9   Connecticut   Reccommended_Restriction    04           17        7307.0
# 10  Connecticut   Reccommended_Restriction    04           18        2431.0
# ...

# %%
#Select Washington DC
df_Washington_DC = df_analysis_internal_restrictions[((df_analysis_internal_restrictions['State']== 'Washington DC'))]
df_Washington_DC = df_Washington_DC[[
    'Country',
    'State' ,
    'InternalRestrictionsDetail' ,
    'Daily_New_Cases',
    'Month' ,
    'Week_Number'
    ]]
df_Washington_DC.groupby(['State', 'InternalRestrictionsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'],ascending= True)
# Out:
#             State InternalRestrictionsDetail Month  Week_Number  Weekly_Cases
# 0   Washington DC                 No_Measure    03            9           0.0
# 1   Washington DC                 No_Measure    03           10           0.0
# 2   Washington DC                 No_Measure    03           11           0.0
# 3   Washington DC   Reccommended_Restriction    03           12         102.0
# 4   Washington DC   Reccommended_Restriction    03           13         240.0
# 5   Washington DC   Reccommended_Restriction    03           14         153.0
# 16  Washington DC       Required_Restriction    04           14         507.0
# 17  Washington DC       Required_Restriction    04           15         873.0
# 18  Washington DC       Required_Restriction    04           16         918.0
# 19  Washington DC       Required_Restriction    04           17        1048.0
# 20  Washington DC       Required_Restriction    04           18         482.0
# ...

# %%
#Select Utah
df_Utah = df_analysis_internal_restrictions[((df_analysis_internal_restrictions['State']== 'Utah'))]
df_Utah = df_Utah[[
    'Country',
    'State' ,
    'InternalRestrictionsDetail' ,
    'Daily_New_Cases',
    'Month' ,
    'Week_Number'
    ]]
df_Utah.groupby(['State', 'InternalRestrictionsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'],ascending= True)
# Out:
#    State InternalRestrictionsDetail Month  Week_Number  Weekly_Cases
# 0   Utah                 No_Measure    03            9           0.0
# 1   Utah                 No_Measure    03           10           1.0
# 2   Utah                 No_Measure    03           11          17.0
# 3   Utah   Reccommended_Restriction    03           12         144.0
# 4   Utah   Reccommended_Restriction    03           13         558.0
# 5   Utah   Reccommended_Restriction    03           14         168.0
# 6   Utah   Reccommended_Restriction    04           14         713.0
# 7   Utah   Reccommended_Restriction    04           15         702.0
# 8   Utah   Reccommended_Restriction    04           16         766.0
# 9   Utah   Reccommended_Restriction    04           17        1054.0
# 10  Utah   Reccommended_Restriction    04           18         549.0
# 11  Utah   Reccommended_Restriction    05           18         503.0
# 12  Utah   Reccommended_Restriction    05           19        1076.0
# ...

# %%
#Select Wyoming
df_Wyoming = df_analysis_internal_restrictions[((df_analysis_internal_restrictions['State']== 'Wyoming'))]
df_Wyoming = df_Wyoming[[
    'Country',
    'State' ,
    'InternalRestrictionsDetail' ,
    'Daily_New_Cases',
    'Month' ,
    'Week_Number'
    ]]
df_Wyoming.groupby(['State', 'InternalRestrictionsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'],ascending= True)
# Out:
#       State InternalRestrictionsDetail Month  Week_Number  Weekly_Cases
# 0   Wyoming                 No_Measure    03            9           0.0
# 1   Wyoming                 No_Measure    03           10           0.0
# 2   Wyoming                 No_Measure    03           11           2.0
# 3   Wyoming   Reccommended_Restriction    03           12          24.0
# 4   Wyoming   Reccommended_Restriction    03           13          60.0
# 5   Wyoming   Reccommended_Restriction    03           14          23.0
# 6   Wyoming   Reccommended_Restriction    04           14          88.0
# 7   Wyoming   Reccommended_Restriction    04           15          73.0
# 8   Wyoming   Reccommended_Restriction    04           16          43.0
# 9   Wyoming   Reccommended_Restriction    04           17         189.0
# 10  Wyoming   Reccommended_Restriction    04           18          57.0
# 11  Wyoming   Reccommended_Restriction    05           18          27.0
# ...

# %%
#Select Hawaii
df_Hawaii = df_analysis_internal_restrictions[((df_analysis_internal_restrictions['State']== 'Hawaii'))]
df_Hawaii = df_Hawaii[[
    'Country',
    'State' ,
    'InternalRestrictionsDetail' ,
    'Daily_New_Cases',
    'Month' ,
    'Week_Number'
    ]]
df_Hawaii.groupby(['State', 'InternalRestrictionsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'],ascending= True)
# Out:
#      State InternalRestrictionsDetail Month  Week_Number  Weekly_Cases
# 0   Hawaii                 No_Measure    03            9           0.0
# 1   Hawaii                 No_Measure    03           10           1.0
# 2   Hawaii                 No_Measure    03           11           5.0
# 3   Hawaii   Reccommended_Restriction    03           12          47.0
# 4   Hawaii   Reccommended_Restriction    03           13          38.0
# 5   Hawaii       Required_Restriction    03           13          58.0
# 6   Hawaii       Required_Restriction    03           14          55.0
# 7   Hawaii       Required_Restriction    04           14         167.0
# 8   Hawaii       Required_Restriction    04           15         128.0
# 9   Hawaii       Required_Restriction    04           16          81.0
# 10  Hawaii       Required_Restriction    04           17          26.0
# 11  Hawaii       Required_Restriction    04           18          12.0
# ...

# %%
#Select Maine
df_Maine = df_analysis_internal_restrictions[((df_analysis_internal_restrictions['State']== 'Maine'))]
df_Maine = df_Maine[[
    'Country',
    'State' ,
    'InternalRestrictionsDetail' ,
    'Daily_New_Cases',
    'Month' ,
    'Week_Number'
    ]]
df_Maine.groupby(['State', 'InternalRestrictionsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'],ascending= True)
# Out:
#     State InternalRestrictionsDetail Month  Week_Number  Weekly_Cases
# 0   Maine                 No_Measure    03            9           0.0
# 1   Maine                 No_Measure    03           10           0.0
# 2   Maine                 No_Measure    03           11           2.0
# 3   Maine   Reccommended_Restriction    03           12          87.0
# 4   Maine   Reccommended_Restriction    03           13         164.0
# 5   Maine   Reccommended_Restriction    03           14          50.0
# 6   Maine   Reccommended_Restriction    04           14          73.0
# 7   Maine       Required_Restriction    04           14          94.0
# 8   Maine       Required_Restriction    04           15         163.0
# 9   Maine       Required_Restriction    04           16         234.0
# 10  Maine       Required_Restriction    04           17         148.0
# 11  Maine       Required_Restriction    04           18          80.0
# ...

# %%
#Select Vermont
df_Vermont = df_analysis_internal_restrictions[((df_analysis_internal_restrictions['State']== 'Vermont'))]
df_Vermont = df_Vermont[[
    'Country',
    'State' ,
    'InternalRestrictionsDetail' ,
    'Daily_New_Cases',
    'Month' ,
    'Week_Number'
    ]]
df_Vermont.groupby(['State', 'InternalRestrictionsDetail', 'Month', 'Week_Number'])['Daily_New_Cases'].sum().reset_index().rename(columns= {'Daily_New_Cases':'Weekly_Cases'}).sort_values(by=['Month', 'Week_Number'],ascending= True)
# Out:
#       State InternalRestrictionsDetail Month  Week_Number  Weekly_Cases
# 0   Vermont                 No_Measure    03            9           0.0
# 1   Vermont                 No_Measure    03           10           1.0
# 2   Vermont                 No_Measure    03           11           1.0
# 3   Vermont       Required_Restriction    03           11           3.0
# 4   Vermont       Required_Restriction    03           12          47.0
# 5   Vermont       Required_Restriction    03           13         183.0
# 6   Vermont       Required_Restriction    03           14          58.0
# 7   Vermont       Required_Restriction    04           14         219.0
# 8   Vermont       Required_Restriction    04           15         215.0
# 9   Vermont       Required_Restriction    04           16          86.0
# 10  Vermont       Required_Restriction    04           17          38.0
# 11  Vermont       Required_Restriction    04           18          15.0
# ...
