# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
#Load Rank Data
df_analysis_rank = pd.read_csv('/content/Analysis_Population_Rank.csv')

# %%
import matplotlib.pyplot as plt

# %%
colors = ["darkorange", "royalblue"]
df_analysis_rank.plot(x= "State", y= ['Population_Rank', 'Confirmed_Cases_Rank'], kind= "bar", figsize= (18, 6), color=colors)
plt.ylabel('State_Performance')
# Out:
# Text(0, 0.5, 'State_Performance')
